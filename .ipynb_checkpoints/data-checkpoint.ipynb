# %%
import pandas as pd
import numpy as np
import scipy

# %%
import dask.dataframe as dd
import dask.array as da

df = dd.read_csv('CUP_IT_train_data.csv')
X = df.head(50000)


df1 = dd.read_csv('CUP_IT_test_data.csv')
X_test = df1.head(10000)

# %%
X.to_csv('data_train.csv')
X_test.to_csv('data_test.csv')
